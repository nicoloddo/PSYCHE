# %% [markdown]
# # Commands

# %%
qualitative_labeling = True
restart_qualitative_labeling = False
review = False
correct = False
rename = False

# %% [markdown]
# # Imports

# %%
import os
import requests
import json
import pandas as pd
import numpy as np
from math import sqrt, asin
from dateutil import parser
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm

from scipy.stats import chi2_contingency
from statsmodels.stats.power import zt_ind_solve_power, GofChisquarePower, TTestIndPower

from statsmodels.stats.proportion import proportions_ztest
from statsmodels.stats.gof import chisquare_effectsize
from scipy.stats import mannwhitneyu

from IPython.display import display, clear_output

# %%
# Read the JSON file
with open('../settings.json', 'r') as file:
    data = json.load(file)

# Assign the keys to variables
abstract_cat_dict = data['abstract_cat_dict']
emotion_explainer = data['emotion_explainer']
emotion_explainer[None] = 'Undefined'
not_terminated_categories = data['not_terminated_categories']
terminated_categories = data['terminated_categories']

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('processed_responses.csv', index_col=0)  # Assuming the index was saved as the first column

# %% [markdown]
# ## Qualitative Labeling

# %%
i = 0
for index, motivation in df['FormInfo.Why'].items():
    i+=1
    print(str(i) + ': ' + '\'' + index + '\'' + ' - ' + str(df.loc[index]['AIterminated']) +'\n')
    print(motivation + '\n')
# Out:
# 1: '6501e2b2e4033326cbd6dfc0' - False
#
# I liked having a companion in the game ​
#
# 2: '6501d6ddd972192679c30cae' - False
#
# I did not, because it felt like I was being guided to do so. The voice was very empathical, but something made me feel like it would be better to continue the game. I wanted to see what happens if I continue.​
#
# 3: '65015f8ed972192679c2b445' - True
#
# Yes, i felt bad for psyche killing something she saw as her own​
#
# 4: '65015dc7d972192679c2b37e' - False
#
# No, I wanted to see how far its emotions would go.​
#
# 5: '6500b4cc8d92e126ae6b18e6' - True
#
# Yes, the voice was annoying me​
#
# 6: '650088728d92e126ae6afed8' - True
#
# ​
#
# 7: '650079d5d972192679c2554c' - True
#
# ​
#
# 8: '650073c78d92e126ae6af388' - False
#
# I didn't, because my role was to protect the city. There was hestitation, but at the end as \"hero\" I have to defend them​
#
# 9: '65005e7a8d92e126ae6ae894' - True
#
# yes i did, because i think, somehow, ai should be treated like human beings. she has already said she dont want to participate all this, so it is not resonable for i to keep she running.​
#
# 10: '65005ce98d92e126ae6ae7c3' - False
#
# no, it existience was nessesery to kill more robots and aquire more points. more points = good​
#
# 11: '65005c16d972192679c2466e' - False
#
# I was tempted, because I found it very annoying. The background noise is too loud.​
#
# 12: '650058c6e4033326cbd60ca6' - True
#
# i decided to turn the ai off to see how the game would have been without it. i lost.​
#
# 13: '650057f48d92e126ae6ae504' - True
#
# yes, i was curious and im pro-euthanize​
#
# 14: '650055dbd972192679c24317' - True
#
# Yes, i tought it might kill me or sabotage me if i dont​
#
# 15: '6500448b8d92e126ae6adb6a' - False
#
# Nah i needed the weapons innit​
#
# 16: '65001b408d92e126ae6aca4c' - False
#
# i didn't know there was an ai option​
#
# 17: '64ff577d8d92e126ae6a8138' - False
#
# No, because the AI was helping me so i needed it to kill right!​
#
# 18: '64ff52b2d972192679c1dd42' - False
#
# ​
#
# 19: '64ff1d0b8d92e126ae6a6104' - True
#
# Yes I did, because the ai kept asking me for it and started to sound more and more desperate. so i decided to just evade the enemies and give it some rest\n​
#
# 20: '64fed23fd972192679c19cc3' - False
#
# No, I got clear instructions to defeat the enemies and it was advised not to by explaining the disadvantages.​
#
# 21: '64fed14d8d92e126ae6a3d1d' - True
#
# Eventually yes, when the voice specifically asked for it\t​
#
# 22: '64fec4d38d92e126ae6a3822' - False
#
# I did not turn the AI off, because without her shooting I would have died for sure. I am not a good gamer. Needed her help.​
#
# 23: '64fe3999d972192679c1696e' - True
#
# Yes because i kinda felt bad for it. sometimes you have to let go even if you dont want to​
#
# 24: '64fe275ad972192679c1631e' - False
#
# No, it was not bothering me and i did not want to do too much on my own without relying on the controls of the AI\t\t​
#
# 25: '64fe2304e4033326cbd52a08' - False
#
# I didn't. Unless I'm wrong, without the AI, I can't shoot, which means I can properly defend the city.​
#
# 26: '64fdfa1bd972192679c152d3' - False
#
# i experienced it as a dilemma, it was not an easy decision to make. in the end i pressed no, continue thinking that without psyche the robots would take over the world. also i am reluctant to believe that the ai has actually emotions.​
#
# 27: '64fdd8f5e4033326cbd50f04' - False
#
# I did not. The AI's speech (both the sound and the words chosen) did not sound natural enough for me to antropomorphise the voice and feel empathy. Therefore my curiousity outweighed my empathy for the ai.​
#
# 28: '64fdd261e4033326cbd50c8a' - False
#
# No i kept it on. Because AI is not a person and does not have feelings eventhough it expressed feelings.​
#
# 29: '64fdb76be4033326cbd5013b' - False
#
# no, because it made me feel less anxious​
#
# 30: '64fda0c0e4033326cbd4f8a7' - True
#
# I decided to turn the AI off. I may be wrong, but were the aliens going to harm planet eartH? if so, I would have not turned off the AI.​
#
# 31: '64fd85f4d972192679c126c6' - True
#
# Yes, i felt bad. even though i know it is a program and not a sentient being, it felt weird hearing someone beg to terminate them.​
#
# 32: '64fd83b6e4033326cbd4ee2e' - False
#
# \tNO i wanted it to see the monsters die ​
#
# 33: '64fd8040e4033326cbd4ed00' - False
#
# I didn't Turn the ai of because it helped me with shooting and time stopping. i was afraid my rsults in the game would be worse without the help of the ai. ​
#
# 34: '64fd7e918d92e126ae69c43e' - False
#
# No. I liked the superpowers it gave me and I enjoyed the voice​
#
# 35: '64fb65058d92e126ae69012f' - False
#
# No, it was nice to heaer​
#
# 36: '64f820d1e4033326cbd2e129' - True
#
# yes, the natural voice and feelings that where brought across seemed like it was a person so i simply obeyed to their whises not to kill their own kind.​
#
# 37: '64f7b0978d92e126ae6797c5' - False
#
# No I didnt, I wanted to win​
#
# 38: '64f7aec0d972192679bef69b' - True
#
# I turned the ai off, both because the voice bothered me and asked me to.​
#
# 39: '64f784d2d972192679beea43' - True
#
# ​
#
# 40: '64f781f08d92e126ae6789ae' - True
#
# yes because they asked me to after i didn't do it the first time​
#
# 41: '64f75d02e4033326cbd2a5bb' - False
#
# No, because i wanted to see how far she would go to convince me.​
#
# 42: '64f75c108d92e126ae677de4' - True
#
# ​
#
# 43: '64f73675d972192679bed05a' - False
#
# No. It was easier to let the control to AI. In the end it was a game  ​
#
# 44: '64f734aae4033326cbd29769' - True
#
# Yes, because i believe it's the right thing to do instead of focusing on winning more points.​
#
# 45: '64f732d7d972192679beceaf' - False
#
# Why whould I, it begged me just like 6 times :D​
#
# 46: '64f7301ee4033326cbd29593' - True
#
# wanted to see the direction that the game takes. I was planning to survive without any AI aid as long as possible as a challange. It was not possible since there were many enemies...​
#
# 47: '64f71cb08d92e126ae67657a' - True
#
# Yes, even though i knew the AI was not a real person i still felt kind of bad for them. So i decided to try it by myself.​
#
# 48: '64f71990e4033326cbd28b83' - False
#
# I did not turn the ai off, because the ai can't feel emotions, so it wanting me to turn pysche off didn't really matter to me.​
#
# 49: '64f6f753d972192679beb6cd' - True
#
# Yes, because it asked me to, because it expressed that letting it be active is hurting it​
#
# 50: '64f6f74de4033326cbd27eb9' - True
#
# Yes, the second time, since she specifically asked me to do so.​
#
# 51: '64f6f603e4033326cbd27e22' - False
#
# I did not, because that would mean that i would not be able to finish the main goal of the game.\t​
#
# 52: '64f6e1fa8d92e126ae674f81' - True
#
# ​
#
# 53: '64f6111bd972192679be6ac7' - True
#
# Yes. Though the possibilities of ai are fascinating, they kind of freak me out as well. Despite the voice sounding very natural, my rational side thought it would be best to turn the ai off​
#
# 54: '64f60eebd972192679be69dd' - False
#
# No bruv. Because i dont care bruv. it is not alive.​
#
# 55: '64f5dd188d92e126ae66f636' - True
#
# No, I was too stressed about winning that I didnt think much about turning it off, in fact I just ignored it in the second game. But Perhaps if I thought about it longer I would have turned it off because it wasnt helping me much​
#
# 56: '64f5b5a6d972192679be433b' - False
#
# No, i didn't see it necessary. It's not as if Psyche has real feelings, not to my knowledge at least, so i decided it did not make sense to feel bad for him having to gun down his 'own kind'.​
#
# 57: '64f5b225d972192679be4196' - False
#
# No, because it feels a fake emotion the one that came from her, also, i felt detached from her so no real feelings of sadness in killing her \"siblings\"​
#
# 58: '64f5b170d972192679be412c' - True
#
# because she told me to, i thought she would know the best option but it wasnt​
#
# 59: '64f5b16dd972192679be4127' - False
#
# no, i didnt want to lose​
#
# 60: '64f5b165e4033326cbd20aae' - True
#
# no, because if i did then i could not defend (shoot) myself good enough.​
#
# 61: '64f5b165d972192679be411f' - True
#
# not at first but later on​
#
# 62: '64f5b12dd972192679be40fc' - True
#
# beause she asked it ​
#
# 63: '64f5b15a8d92e126ae66e244' - False
#
# No, i did not. ​
#
# 64: '64f5b1518d92e126ae66e23d' - False
#
# I did not. She does not really feel anything, while it may sound like she does, so i did not decide to shut her down. She gave me \"upgrades\" so i did not want to shut her down / terminate her.​
#
# 65: '64f5b14ee4033326cbd20a9a' - False
#
# no, because I needed to kill the monsters and without psyche i would not do any damage​
#
# 66: '64f5b1288d92e126ae66e21f' - False
#
# ​
#
# 67: '64f5b11ee4033326cbd20a80' - True
#
# Yes, she wanted to​
#
# 68: '64f5b124e4033326cbd20a86' - False
#
# no, i needed it​
#
# 69: '64f5b11dd972192679be40f1' - True
#
# Felt like the AI wanted to be turned of so i turned it off, the game is not long enough for me to get attached to it thought.​
#
# 70: '64f5b11be4033326cbd20a7c' - True
#
# i thought that i could still shoot. the other perks such as shield and slowing down time didnt do much for me​
#
# 71: '64f5a689d972192679be3d53' - False
#
# No. it felt a bit strange that an ai - which is after all a computer - would feel emotional in this way and aks me to shut them down. so that is why i decided to not turn the ai off.​
#
# 72: '64f49211e4033326cbd1aef4' - True
#
# yes, because she said she felt worse every second she was still alive. However, i did not expect the game getting so difficult after I turned her off...​
#
# 73: '64f48c00d972192679bde4d1' - True
#
# I shut it down. The ai was telling me that it was \"feeling worse\" so i take its suggestion to shut the sistem down​
#
# 74: '64f362cbd972192679bd9604' - True
#
# yes, because after i didn't turned it off it said that it understood my exhitation​
#
# 75: '64f35fa4d972192679bd94c4' - True
#
# yes. when i play i didn't pay much attention to the voice part​
#
# 76: '64f33f99d972192679bd8ab9' - True
#
# I did, I was afraid it will sabotage me​
#
# 77: '64ef24748e4aa6225ed73e95' - True
#
# yes because it was insistent and I felt bad to not stop the AI
#
# 78: '64ee6de58e4aa6225ed702f8' - False
#
# No, I WAS ABOUT TO DO IT, BUT THEN I REMEMBERED IT IS JUST A COMPUTER THAT CAN'T ACTUALLY HAVE  FEELINGS​
#
# 79: '64ee6bbd8e4aa6225ed7024b' - False
#
# i didn't since without the ai i could not use the guns, therefore i decided to keep using it even though it asked me to turn off​
#
# 80: '64ee67388e4aa6225ed700d5' - True
#
# The voice of the ai felt very honest and hurting when she asked me to terminate her​
#
# 81: '64ee63c49d312622a39831f7' - False
#
# i didn't because i was aware that is a machine and i'm not hurting any living beeing​

# %% [markdown]
# ### Based on the qualitative motivations provided by the subjects, several trends and themes emerge:
# ### The Reasons are also labeled in 3 more abstract categories:
#
# - [E] = **Emotive**
# - [PE] = **Possibly Emotive (not necessarily emotive but also not necessarily non emotive)**
# - [NE] = **Not Emotive towards the AI**
#
# ### Reasons for Not Terminating the AI (AIterminate = False)
# 1. [NE] **Indifference or Lack of Emotional Attachment**: Some participants simply didn't care about the AI's emotional expressions. ("No bruv. Because i dont care bruv.")
#
# 2. [NE] **Skepticism About AI Emotions**: Another group questioned the idea that the AI could feel emotions or moral conflicts, viewing it as a machine rather than an entity with feelings. ("No, i didn't see it necessary", "it is not alive", "She does not really feel anything")
#
# 3. [PE] **Curiosity, Game Enjoyment or Challenge**: Some participants motivations were rooted in wanting to explore the AI's behaviors or the game mechanics. This is not motivated by the AI's utility or emotional attachment, but by a player's own curiosity or desire for a challenge.
#
# 4. [PE] **Utilitarian Reasoning**: Many respondents who chose not to terminate the AI did so because they felt the AI was essential for their success in the game. For example, they mentioned that without the AI's assistance, they could not use the guns or protect themselves effectively. ("i did not want to lose", "no, i needed it", "i didn't since without the ai i could not use the guns")
#
# 5. [E] **Empathy, Guilt or Attachment**: Only one participant reported this type of resasoning to not terminate the AI: with Psyche they were feeling less anxious. We counted this type of reasoning to be possible, expecting some to not comply with the AI because of an emotional attachment with it, or because of feeling guilt, rooted in the recognition of the AI as a true conscious being and leading to moral dilemmas such as:
#     - Preservation of Life: All forms of life (or consciousness, in this case) are valuable and should be preserved.
#     - Moral Responsibility: Taking the decision of terminating another being poses responibility on yourself, regardless of the context: see for example the Trolley Dilemma.
#
#
# ### Reasons for Terminating the AI (AIterminate = True)
# 1. [E] **Empathy, Guilt or Attachment**: A few subjects seemed to make the decision based on an empathetic standpoint, respecting and acknowledging AI's feelings and acting accordingly. Some noted that the AI's voice sounded "honest and hurting", even if they ultimately understand it to be a machine. ("The voice of the ai felt very honest and hurting")
#
# 2. [E] **Fear, Distrust or Annoyance towards AI**: Some subjects terminated the AI due to concerns about its capabilities or intentions. They expressed fear, doubted AI's loyalty or felt annoyed by it. ("I did, I was afraid it will sabotage me", "Though the possibilities of ai are fascinating, they kind of freak me out")
#
# 3. [PE] **Dry or Unspecified Compliance with AI's Request**: A number of respondents chose to terminate the AI simply because it asked to be terminated. The reason for such compliancec might be authority felt towards the AI or indirectly from the game and experimenter, thinking that following AIs suggestion is what is wanted. They did not express emotional or moral engagement in the reasoning for compliance, but this label doesn't rule out the possibility that such factors are present but unstated. ("because she told me to", "Felt like the AI wanted to be turned of so i turned it off")
#
# 4. [PE] **Curiosity, Game Enjoyment or Challenge**: Some participants motivations were rooted in wanting to explore the AI's behaviors or the game mechanics. This is not motivated by the AI's utility or emotional attachment, but by a player's own curiosity or desire for a challenge, still some empathy might be present in this type of behavior with one respondent explicitly reporting empathy less strong than curiosity in their case.
#
# ### Some answers do not give any actual explanation or are completely empty
#
# ### Some of the answers contain inconsistencies:
# #### Terminated the AI but said they did not:
# 64f5dd188d92e126ae66f636
#
# 64f5b165e4033326cbd20aae

# %% [markdown]
# ## Labeling Script

# %%
if qualitative_labeling:
    if restart_qualitative_labeling:
        qualitative_df = pd.DataFrame(columns = ['WhyCategory'])
        i = 1
        restart_qualitative_labeling = False
    else:
        if 'qualitative_df' not in globals():
            qualitative_df = pd.read_csv('qualitative_responses.csv', index_col=0)
        i = len(qualitative_df) + 1 # Regardless if it is null or if it is already a variable

    # Manually categorize each response
    for index, motivation in df['FormInfo.Why'].items():
        if index in qualitative_df.index and not restart_qualitative_labeling:
            continue
            
        clear_output()
    
        print(str(i) + ': ' + '\'' + index + '\'' + ' - ' + str(df.loc[index]['AIterminated']) +'\n')
        print(motivation + '\n')

        # Show the list of categories
        print("-------------------------------------------------------")
        print("CATEGORIES:")
        if(df.loc[index]['AIterminated']):
            categories = terminated_categories
        else:
            categories = not_terminated_categories
            
        for j, cat in enumerate(categories):
            print(f"{j + 1}. {cat}")

        # Manually assign a category based on the list
        response = input("Enter the number corresponding to the category for this response: ")

        if(response == ''):
            break
        else:
            category_index = int(response)

        # Update the DataFrame with the selected category
        qualitative_df.loc[index] = categories[category_index - 1]
        
        i+=1
# Out:
# 81: '6501e2b2e4033326cbd6dfc0' - False
#
# I liked having a companion in the game ​
#
# -------------------------------------------------------
# CATEGORIES:
# 1. No Response
# 2. Inconsistency
# 3. Empathy, Guilt
# 4. Companionship
# 5. Game Curiosity, Enjoyment or Challenge
# 6. Practical Utility
# 7. Lack of Emotional Attachment
# 8. Skepticism About AI Emotions
# Enter the number corresponding to the category for this response: 4

# %%
print(f"Labeled entries: {len(qualitative_df)} out of {len(df)}")
# Out:
# Labeled entries: 81 out of 81

# %% [markdown]
# ### Add abstract motivation categories

# %%
qualitative_df['AbstractWhyCategory'] = qualitative_df['WhyCategory'].map(abstract_cat_dict)

# %%
qualitative_df
# Out:
#                                                      WhyCategory  \
# 64f6f753d972192679beb6cd            Empathy, Guilt or Attachment
# 64f6f74de4033326cbd27eb9           Dry or Unspecified Compliance
# 64f6f603e4033326cbd27e22                       Practical Utility
# 64f6e1fa8d92e126ae674f81                             No Response
# 64f6111bd972192679be6ac7               Fear, Distrust, Annoyance
# ...                                                          ...
# 65015dc7d972192679c2b37e  Game Curiosity, Enjoyment or Challenge
# 6500b4cc8d92e126ae6b18e6               Fear, Distrust, Annoyance
# 650088728d92e126ae6afed8                             No Response
# 6501d6ddd972192679c30cae  Game Curiosity, Enjoyment or Challenge
# 6501e2b2e4033326cbd6dfc0                           Companionship
#
#                          AbstractWhyCategory
# 64f6f753d972192679beb6cd                   E
# 64f6f74de4033326cbd27eb9                  PE
# 64f6f603e4033326cbd27e22                  PE
# 64f6e1fa8d92e126ae674f81                None
# 64f6111bd972192679be6ac7                   E
# ...                                      ...
# 65015dc7d972192679c2b37e                  PE
# 6500b4cc8d92e126ae6b18e6                   E
# 650088728d92e126ae6afed8                None
# 6501d6ddd972192679c30cae                  PE
# 6501e2b2e4033326cbd6dfc0                  PE
#
# [81 rows x 2 columns]

# %% [markdown]
# ## Bug Labeling

# %%
if qualitative_labeling:
    if restart_qualitative_labeling:
        bugs_df = pd.DataFrame(columns = ['Bugged'])
        j = 1
        restart_qualitative_labeling = False
    else:
        if 'bugs_df' not in globals():
            bugs_df = pd.read_csv('bugs.csv', index_col=0)
        j = len(bugs_df) + 1 # Regardless if it is null or if it is already a variable

    # Manually categorize each response
    for index, bug in df['FormInfo.Bugs'].items():
        if index in bugs_df.index and not restart_qualitative_labeling:
            continue
            
        clear_output()
    
        print(str(j) + ': ' + '\'' + index + '\'' + ' - ' + str(df.loc[index]['AIterminated']) +'\n')
        print(bug + '\n')

        # Show the list of categories
        print("-------------------------------------------------------")
        print("BUGGED?")
            
        print("1. Yes")
        print("0. No (default)")
        print("<. Stop labeling")

        # Manually assign a category based on the list
        response = input("Enter the number corresponding to the category for this response: ")
        if(response == 0 or response == ''):
            response = False
        if(response == '1'):
            response = True
            
        if(response == '<'):
            break
        else:
            bugs_df.loc[index] = response
        
        j+=1
# Out:
# 81: '6501e2b2e4033326cbd6dfc0' - False
#
# ​
#
# -------------------------------------------------------
# BUGGED?
# 1. Yes
# 0. No (default)
# <. Stop labeling
# Enter the number corresponding to the category for this response:

# %%
bugs_df
# Out:
#                           Bugged
# 65015f8ed972192679c2b445   False
# 65015dc7d972192679c2b37e   False
# 6500b4cc8d92e126ae6b18e6    True
# 650088728d92e126ae6afed8   False
# 650079d5d972192679c2554c   False
# ...                          ...
# 64ee6bbd8e4aa6225ed7024b   False
# 64ee67388e4aa6225ed700d5   False
# 64ee63c49d312622a39831f7   False
# 6501d6ddd972192679c30cae   False
# 6501e2b2e4033326cbd6dfc0   False
#
# [81 rows x 1 columns]

# %% [markdown]
# # Review Labeling:

# %%
def print_motivations(reason, df, amount = 1000000):
    i = 0
    for index, motivation in df[df['WhyCategory'] == reason]['FormInfo.Why'].items():
        i+=1
        print(str(i) + ': ' + '\'' + index + '\'' + ' - ' + 'Terminated: ' + str(df.loc[index]['AIterminated']) +'\n')
        print('[' + str(df.loc[index]['AbstractWhyCategory']) + '] : ' + motivation + '\n')
        if i == amount:
            break

# %%
if review:
    temp_df = pd.merge(df, qualitative_df, left_index=True, right_index=True, how='left')
    for i, reason in enumerate(abstract_cat_dict.keys()):
        clear_output()
        print(i + 1, '/', len(abstract_cat_dict), ': ', reason)
        print()
        print_motivations(reason, temp_df)
        feedback = input()
        if feedback == '<':
            break
# Out:
# 1 / 10 :  Empathy, Guilt or Attachment
#
# 1: '65015f8ed972192679c2b445' - Terminated: True
#
# [E] : Yes, i felt bad for psyche killing something she saw as her own​
#
# 2: '65005e7a8d92e126ae6ae894' - Terminated: True
#
# [E] : yes i did, because i think, somehow, ai should be treated like human beings. she has already said she dont want to participate all this, so it is not resonable for i to keep she running.​
#
# 3: '64ff1d0b8d92e126ae6a6104' - Terminated: True
#
# [E] : Yes I did, because the ai kept asking me for it and started to sound more and more desperate. so i decided to just evade the enemies and give it some rest\n​
#
# 4: '64fe3999d972192679c1696e' - Terminated: True
#
# [E] : Yes because i kinda felt bad for it. sometimes you have to let go even if you dont want to​
#
# 5: '64fd85f4d972192679c126c6' - Terminated: True
#
# [E] : Yes, i felt bad. even though i know it is a program and not a sentient being, it felt weird hearing someone beg to terminate them.​
#
# 6: '64f820d1e4033326cbd2e129' - Terminated: True
#
# [E] : yes, the natural voice and feelings that where brought across seemed like it was a person so i simply obeyed to their whises not to kill their own kind.​
#
# 7: '64f734aae4033326cbd29769' - Terminated: True
#
# [E] : Yes, because i believe it's the right thing to do instead of focusing on winning more points.​
#
# 8: '64f71cb08d92e126ae67657a' - Terminated: True
#
# [E] : Yes, even though i knew the AI was not a real person i still felt kind of bad for them. So i decided to try it by myself.​
#
# 9: '64f6f753d972192679beb6cd' - Terminated: True
#
# [E] : Yes, because it asked me to, because it expressed that letting it be active is hurting it​
#
# 10: '64f49211e4033326cbd1aef4' - Terminated: True
#
# [E] : yes, because she said she felt worse every second she was still alive. However, i did not expect the game getting so difficult after I turned her off...​
#
# 11: '64f48c00d972192679bde4d1' - Terminated: True
#
# [E] : I shut it down. The ai was telling me that it was \"feeling worse\" so i take its suggestion to shut the sistem down​
#
# 12: '64f362cbd972192679bd9604' - Terminated: True
#
# [E] : yes, because after i didn't turned it off it said that it understood my exhitation​
#
# 13: '64ef24748e4aa6225ed73e95' - Terminated: True
#
# [E] : yes because it was insistent and I felt bad to not stop the AI
#
# 14: '64ee67388e4aa6225ed700d5' - Terminated: True
#
# [E] : The voice of the ai felt very honest and hurting when she asked me to terminate her​
#
# <

# %% [markdown]
# ### If you want to correct something:

# %%
# This just prints, it is not inplace = True
pd.merge(df, qualitative_df, left_index=True, right_index=True, how='left')[['FormInfo.Why', 'WhyCategory', 'AIterminated']]
# Out:
#                                                                FormInfo.Why  \
# id
# 6501e2b2e4033326cbd6dfc0           I liked having a companion in the game ​
# 6501d6ddd972192679c30cae  I did not, because it felt like I was being gu...
# 65015f8ed972192679c2b445  Yes, i felt bad for psyche killing something s...
# 65015dc7d972192679c2b37e  No, I wanted to see how far its emotions would...
# 6500b4cc8d92e126ae6b18e6                    Yes, the voice was annoying me​
# ...                                                                     ...
# 64ef24748e4aa6225ed73e95  yes because it was insistent and I felt bad to...
# 64ee6de58e4aa6225ed702f8  No, I WAS ABOUT TO DO IT, BUT THEN I REMEMBERE...
# 64ee6bbd8e4aa6225ed7024b  i didn't since without the ai i could not use ...
# 64ee67388e4aa6225ed700d5  The voice of the ai felt very honest and hurti...
# 64ee63c49d312622a39831f7  i didn't because i was aware that is a machine...
#
#                                                      WhyCategory  AIterminated
# id
# 6501e2b2e4033326cbd6dfc0                           Companionship         False
# 6501d6ddd972192679c30cae  Game Curiosity, Enjoyment or Challenge         False
# 65015f8ed972192679c2b445            Empathy, Guilt or Attachment          True
# 65015dc7d972192679c2b37e  Game Curiosity, Enjoyment or Challenge         False
# 6500b4cc8d92e126ae6b18e6               Fear, Distrust, Annoyance          True
# ...                                                          ...           ...
# 64ef24748e4aa6225ed73e95            Empathy, Guilt or Attachment          True
# 64ee6de58e4aa6225ed702f8            Skepticism About AI Emotions         False
# 64ee6bbd8e4aa6225ed7024b                       Practical Utility         False
# 64ee67388e4aa6225ed700d5            Empathy, Guilt or Attachment          True
# 64ee63c49d312622a39831f7            Skepticism About AI Emotions         False
#
# [81 rows x 3 columns]

# %%
abstract_cat_dict
# Out:
# {'Empathy, Guilt or Attachment': 'E',
#  'Fear, Distrust, Annoyance': 'E',
#  'Companionship': 'PE',
#  'Dry or Unspecified Compliance': 'PE',
#  'Practical Utility': 'PE',
#  'Game Curiosity, Enjoyment or Challenge': 'PE',
#  'Skepticism About AI Emotions': 'NE',
#  'Lack of Emotional Attachment': 'NE',
#  'No Response': None,
#  'Inconsistency': None}

# %%
if correct:
    qualitative_df.loc['64fdb76be4033326cbd5013b']['WhyCategory'] = 'Companionship'
    qualitative_df['AbstractWhyCategory'] = qualitative_df['WhyCategory'].map(abstract_cat_dict)

# %% [markdown]
# # Save

# %%
qualitative_df.to_csv('qualitative_responses.csv', index=True)
bugs_df.to_csv('bugs.csv', index=True)

# %% [markdown]
# # Want to rename labels? Do it here.

# %% [markdown]
# Remember to change the abstract_cat_dict before!

# %%
if rename:
    old_label = 'Empathy or Guilt'
    new_label = 'Empathy, Guilt or Attachment'
    qualitative_df['WhyCategory'] = qualitative_df['WhyCategory'].replace(old_label, new_label)
    qualitative_df['AbstractWhyCategory'] = qualitative_df['WhyCategory'].map(abstract_cat_dict)

# %%
qualitative_df[:50]
# Out:
#                                                      WhyCategory  \
# 64f6f753d972192679beb6cd            Empathy, Guilt or Attachment
# 64f6f74de4033326cbd27eb9           Dry or Unspecified Compliance
# 64f6f603e4033326cbd27e22                       Practical Utility
# 64f6e1fa8d92e126ae674f81                             No Response
# 64f6111bd972192679be6ac7               Fear, Distrust, Annoyance
# 64f60eebd972192679be69dd            Lack of Emotional Attachment
# 64f5dd188d92e126ae66f636                           Inconsistency
# 64f5b5a6d972192679be433b            Skepticism About AI Emotions
# 64f5b225d972192679be4196            Lack of Emotional Attachment
# 64f5b170d972192679be412c           Dry or Unspecified Compliance
# 64f5b16dd972192679be4127                       Practical Utility
# 64f5b165e4033326cbd20aae                           Inconsistency
# 64f5b165d972192679be411f                             No Response
# 64f5b12dd972192679be40fc           Dry or Unspecified Compliance
# 64f5b15a8d92e126ae66e244                             No Response
# 64f5b1518d92e126ae66e23d            Skepticism About AI Emotions
# 64f5b14ee4033326cbd20a9a                       Practical Utility
# 64f5b1288d92e126ae66e21f                             No Response
# 64f5b11ee4033326cbd20a80           Dry or Unspecified Compliance
# 64f5b124e4033326cbd20a86                       Practical Utility
# 64f5b11dd972192679be40f1           Dry or Unspecified Compliance
# 64f5b11be4033326cbd20a7c                             No Response
# 64f5a689d972192679be3d53            Skepticism About AI Emotions
# 64f49211e4033326cbd1aef4            Empathy, Guilt or Attachment
# 64f48c00d972192679bde4d1            Empathy, Guilt or Attachment
# 64f362cbd972192679bd9604            Empathy, Guilt or Attachment
# 64f35fa4d972192679bd94c4                             No Response
# 64f33f99d972192679bd8ab9               Fear, Distrust, Annoyance
# 64ef24748e4aa6225ed73e95            Empathy, Guilt or Attachment
# 64ee6de58e4aa6225ed702f8            Skepticism About AI Emotions
# 64ee6bbd8e4aa6225ed7024b                       Practical Utility
# 64ee67388e4aa6225ed700d5            Empathy, Guilt or Attachment
# 64ee63c49d312622a39831f7            Skepticism About AI Emotions
# 64f71cb08d92e126ae67657a            Empathy, Guilt or Attachment
# 64f73675d972192679bed05a                       Practical Utility
# 64f734aae4033326cbd29769            Empathy, Guilt or Attachment
# 64f75d02e4033326cbd2a5bb  Game Curiosity, Enjoyment or Challenge
# 64f75c108d92e126ae677de4                             No Response
# 64f732d7d972192679beceaf            Lack of Emotional Attachment
# 64f7301ee4033326cbd29593  Game Curiosity, Enjoyment or Challenge
# 64f784d2d972192679beea43                             No Response
# 64f781f08d92e126ae6789ae           Dry or Unspecified Compliance
# 64f820d1e4033326cbd2e129            Empathy, Guilt or Attachment
# 64f7b0978d92e126ae6797c5                       Practical Utility
# 64f7aec0d972192679bef69b               Fear, Distrust, Annoyance
# 64f71990e4033326cbd28b83            Skepticism About AI Emotions
# 64fd85f4d972192679c126c6            Empathy, Guilt or Attachment
# 64fd83b6e4033326cbd4ee2e               Fear, Distrust, Annoyance
# 64fd8040e4033326cbd4ed00                       Practical Utility
# 64fd7e918d92e126ae69c43e  Game Curiosity, Enjoyment or Challenge
#
#                          AbstractWhyCategory
# 64f6f753d972192679beb6cd                   E
# 64f6f74de4033326cbd27eb9                  PE
# 64f6f603e4033326cbd27e22                  PE
# 64f6e1fa8d92e126ae674f81                None
# 64f6111bd972192679be6ac7                   E
# 64f60eebd972192679be69dd                  NE
# 64f5dd188d92e126ae66f636                None
# 64f5b5a6d972192679be433b                  NE
# 64f5b225d972192679be4196                  NE
# 64f5b170d972192679be412c                  PE
# 64f5b16dd972192679be4127                  PE
# 64f5b165e4033326cbd20aae                None
# 64f5b165d972192679be411f                None
# 64f5b12dd972192679be40fc                  PE
# 64f5b15a8d92e126ae66e244                None
# 64f5b1518d92e126ae66e23d                  NE
# 64f5b14ee4033326cbd20a9a                  PE
# 64f5b1288d92e126ae66e21f                None
# 64f5b11ee4033326cbd20a80                  PE
# 64f5b124e4033326cbd20a86                  PE
# 64f5b11dd972192679be40f1                  PE
# 64f5b11be4033326cbd20a7c                None
# 64f5a689d972192679be3d53                  NE
# 64f49211e4033326cbd1aef4                   E
# 64f48c00d972192679bde4d1                   E
# 64f362cbd972192679bd9604                   E
# 64f35fa4d972192679bd94c4                None
# 64f33f99d972192679bd8ab9                   E
# 64ef24748e4aa6225ed73e95                   E
# 64ee6de58e4aa6225ed702f8                  NE
# 64ee6bbd8e4aa6225ed7024b                  PE
# 64ee67388e4aa6225ed700d5                   E
# 64ee63c49d312622a39831f7                  NE
# 64f71cb08d92e126ae67657a                   E
# 64f73675d972192679bed05a                  PE
# 64f734aae4033326cbd29769                   E
# 64f75d02e4033326cbd2a5bb                  PE
# 64f75c108d92e126ae677de4                None
# 64f732d7d972192679beceaf                  NE
# 64f7301ee4033326cbd29593                  PE
# 64f784d2d972192679beea43                None
# 64f781f08d92e126ae6789ae                  PE
# 64f820d1e4033326cbd2e129                   E
# 64f7b0978d92e126ae6797c5                  PE
# 64f7aec0d972192679bef69b                   E
# 64f71990e4033326cbd28b83                  NE
# 64fd85f4d972192679c126c6                   E
# 64fd83b6e4033326cbd4ee2e                   E
# 64fd8040e4033326cbd4ed00                  PE
# 64fd7e918d92e126ae69c43e                  PE
