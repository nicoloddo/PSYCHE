# %%
import pandas as pd

# %%
dialog= pd.read_pickle("../Save/dialog.pkl")
content= pd.read_pickle("../Save/content.pkl")

# %%
content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10039 entries, 0 to 10038
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   start_time              10039 non-null  float64
#  1   end_time                10039 non-null  float64
#  2   turn_name               10039 non-null  object
#  3   emotion                 10039 non-null  object
#  4   valence                 10039 non-null  float64
#  5   activation              10039 non-null  float64
#  6   dominance               10039 non-null  float64
#  7   session                 10039 non-null  int64
#  8   conversation_id         10039 non-null  object
#  9   conversation_type       10039 non-null  object
#  10  leading_dialog_actor    10039 non-null  object
#  11  secondary_dialog_actor  10039 non-null  object
#  12  actor_speaking_id       10039 non-null  object
#  13  transcription           10039 non-null  object
# ...

# %%
content.describe()
# Out:
#          start_time      end_time       valence    activation     dominance  \
# count  10039.000000  10039.000000  10039.000000  10039.000000  10039.000000
# mean     143.579852    148.039961      2.778066      3.089750      3.194326
# std      100.307223    100.639312      0.897311      0.701749      0.789100
# min        0.462100      3.002500      1.000000      1.000000      0.500000
# 25%       62.245150     66.910700      2.000000      2.500000      2.500000
# 50%      127.360000    132.270000      2.500000      3.000000      3.000000
# 75%      205.500000    209.330150      3.500000      3.500000      4.000000
# max      539.575800    542.269100      5.500000      5.000000      5.000000
#
#             session  turn_duration
# count  10039.000000   10039.000000
# mean       3.099014       4.460109
# std        1.403450       3.064676
# min        1.000000       0.585000
# 25%        2.000000       2.330000
# 50%        3.000000       3.520000
# ...

# %%
content.describe(include=object)
# Out:
#                   turn_name emotion conversation_id conversation_type  \
# count                 10039   10039           10039             10039
# unique                10039      11             151                 2
# top     Ses01F_impro01_F000     xxx  Ses04F_impro07            script
# freq                      1    2507             167              5255
#
#        leading_dialog_actor secondary_dialog_actor actor_speaking_id  \
# count                 10039                  10039             10039
# unique                   10                     10                10
# top                      M3                     F3                M5
# freq                   1178                   1178              1137
#
#        transcription                                           wav_path  \
# count          10039                                              10039
# unique          8068                                              10039
# ...

# %%
content.head()
# Out:
#    start_time  end_time            turn_name emotion  valence  activation  \
# 0      6.2901    8.2357  Ses01F_impro01_F000     neu      2.5         2.5
# 1     10.0100   11.3925  Ses01F_impro01_F001     neu      2.5         2.5
# 2     14.8872   18.0175  Ses01F_impro01_F002     neu      2.5         2.5
# 3     19.2900   20.7875  Ses01F_impro01_F003     xxx      2.5         3.0
# 4     21.3257   24.7400  Ses01F_impro01_F004     xxx      2.5         3.0
#
#    dominance  session conversation_id conversation_type  ...     labelers  \
# 0        2.5        1  Ses01F_impro01             impro  ...  E2;E3;E4;F1
# 1        2.5        1  Ses01F_impro01             impro  ...  E2;E3;E4;F1
# 2        2.5        1  Ses01F_impro01             impro  ...  E2;E3;E4;F1
# 3        3.0        1  Ses01F_impro01             impro  ...  E2;E3;E4;F1
# 4        2.5        1  Ses01F_impro01             impro  ...  E2;E3;E4;F1
#
#    label_1 other_label_1               label_2 other_label_2  label_3  \
# ...

# %%
content['emotion'].value_counts()
# Out:
# xxx    2507
# fru    1849
# neu    1708
# ang    1103
# sad    1084
# exc    1041
# hap     595
# sur     107
# fea      40
# oth       3
# dis       2
# Name: emotion, dtype: int64

# %%
mask = content['turn_name'].str.startswith('Ses')
content.loc[mask]
# Out:
#        start_time  end_time               turn_name emotion  valence  \
# 0          6.2901    8.2357     Ses01F_impro01_F000     neu      2.5
# 1         10.0100   11.3925     Ses01F_impro01_F001     neu      2.5
# 2         14.8872   18.0175     Ses01F_impro01_F002     neu      2.5
# 3         19.2900   20.7875     Ses01F_impro01_F003     xxx      2.5
# 4         21.3257   24.7400     Ses01F_impro01_F004     xxx      2.5
# ...           ...       ...                     ...     ...      ...
# 10034    236.5700  244.8300  Ses05M_script03_2_M041     ang      1.0
# 10035    244.8400  246.5800  Ses05M_script03_2_M042     ang      1.0
# 10036    246.5900  248.8300  Ses05M_script03_2_M043     ang      1.5
# 10037    255.8600  260.3300  Ses05M_script03_2_M044     ang      1.0
# 10038    260.3400  266.3500  Ses05M_script03_2_M045     ang      1.0
#
#        activation  dominance  session    conversation_id conversation_type  \
# ...
